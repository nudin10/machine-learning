# %%
import numpy as np

X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import os

mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
plt.plot(X, y, "b.")
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.axis([0, 2, 0, 15])
plt.show()

# %%
X_b = np.c_[np.ones((100, 1)), X]
theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)

# %%
theta_best
# Out:
# array([[4.10204053],
#        [2.92758805]])

# %%
X_new = np.array([[0], [2]])
X_new_b = np.c_[np.ones((2,1)), X_new] #add x0 = 1 to each instance; x0 is the bias term

y_pred = X_new_b.dot(theta_best)
y_pred
# Out:
# array([[4.10204053],
#        [9.95721662]])

# %%
X_new_b
# Out:
# array([[1., 0.],
#        [1., 2.]])

# %%
plt.plot(X_new, y_pred, "r-")
plt.plot(X, y, "b.")
plt.axis([0,2,0,15])
plt.show()

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(X, y)
lin_reg.intercept_, lin_reg.coef_
# Out:
# (array([4.10204053]), array([[2.92758805]]))

# %%
lin_reg.predict(X_new)
# Out:
# array([[4.10204053],
#        [9.95721662]])

# %%
theta_best_svd, residuals, rank, s = np.linalg.lstsq(X_b, y, rcond=1e-6)
theta_best_svd
# Out:
# array([[4.10204053],
#        [2.92758805]])

# %%
X_b.shape
# Out:
# (100, 2)

# %%
np.linalg.pinv(X_b).shape #pinv is the pseudoinverse of given matrix -> lookup Moore-Penrose inverse
# Out:
# (2, 100)
